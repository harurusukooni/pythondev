# %%
word = []
word = list("abcdefhijklmgopqrstuvwxyz")
word_count = dict.fromkeys(word,0)
print(word_count)

user_input = int(input("英単語を入力してください："))

while score >= 0:
 score=int(input("点数を入力してください："))
 print("点数を入力してください：" ,score, ) 
 total += score
 i += 1
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'g': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0}
# 2

# %%
user_input = input("英単語を入力してください：")

while True :
   if not user_input == "" :
    print("英単語を入力してください：" ,user_input, ) 
    user_set = []
    user_set.append(user_input)
         
   if user_input == "" :
    print("英単語を入力してください：" ,"", ) 
     break



print("入力した英単語：",user_set,)
# Out:
# 英単語を入力してください： dog
# 入力した英単語： ['dog']
#   Cell In[73], line 11
#     break
#     ^
# IndentationError: unexpected indent

# %%
 word_set = set()
 word_set.add("user_input")

# %%
# Out:
#   Cell In[62], line 4
#     user_input == not "":
#                   ^
# SyntaxError: invalid syntax
