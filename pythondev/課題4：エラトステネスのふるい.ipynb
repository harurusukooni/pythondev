# %%
for i in range(2,20):
   if i % 3 == 1 or i % 3 == 2:
      continue
   print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
for i in range(2,20):
 if i == 2 or i % 2 == 1:
  print(i)
# Out:
# 2
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19
